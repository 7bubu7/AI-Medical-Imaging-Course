# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a empty DataFrame
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# add a column
df['name'] = ['A', 'B', 'C']
df
# Out:
#   name
# 0    A
# 1    B
# 2    C

# %%
# add 2nd and 3rd column
df['height'] = [150, 180, 170]
df['weight'] = [45, 70, 64]
df
# Out:
#   name  height  weight
# 0    A     150      45
# 1    B     180      70
# 2    C     170      64

# %%
# Create DataFrame with Values
df = pd.DataFrame(
    {
        'name': ['A', 'B', 'C'],
        'height': [150, 180, 170],
        'weight': [45, 70, 64]
    }
)
df
# Out:
#   name  height  weight
# 0    A     150      45
# 1    B     180      70
# 2    C     170      64

# %%
# First 2 rows
df.head(2)
# Out:
#   name  height  weight
# 0    A     150      45
# 1    B     180      70

# %%
# Last 2 rows
df.tail(2)
# Out:
#   name  height  weight
# 1    B     180      70
# 2    C     170      64

# %%
# index and columns
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# Index(['name', 'height', 'weight'], dtype='object')

# %%
# convert to numpy array
df_numpy = df.to_numpy()
df_numpy
print(df_numpy.shape)
print(df_numpy)
# Out:
# (3, 3)
# [['A' 150 45]
#  ['B' 180 70]
#  ['C' 170 64]]

# %%
df.describe()
# Out:
#            height     weight
# count    3.000000   3.000000
# mean   166.666667  59.666667
# std     15.275252  13.051181
# min    150.000000  45.000000
# 25%    160.000000  54.500000
# 50%    170.000000  64.000000
# 75%    175.000000  67.000000
# max    180.000000  70.000000

# %% [markdown]
# ### Selection

# %%
# Columns 
print(df['name'])
print(df['weight'])
# Out:
# 0    A
# 1    B
# 2    C
# Name: name, dtype: object
# 0    45
# 1    70
# 2    64
# Name: weight, dtype: int64

# %%
# Rows
df[0:2]
# Out:
#   name  height  weight
# 0    A     150      45
# 1    B     180      70

# %%
# select by position
df.iloc[2]
# Out:
# name        C
# height    170
# weight     64
# Name: 2, dtype: object

# %%
# select first 2 rows and last column
df.iloc[:2, 2]
# Out:
# 0    45
# 1    70
# Name: weight, dtype: int64

# %%
# select height > 160
df[df['height'] > 160]
# Out:
#   name  height  weight
# 1    B     180      70
# 2    C     170      64

# %% [markdown]
# ### Setting

# %%
df['height>160'] = df['height'] > 160
df
# Out:
#   name  height  weight  height>160
# 0    A     150      45       False
# 1    B     180      70        True
# 2    C     170      64        True

# %%
df['BMI'] = df['weight'] / ((df['height'] / 100) ** 2)
df
# Out:
#   name  height  weight  height>160        BMI
# 0    A     150      45       False  20.000000
# 1    B     180      70        True  21.604938
# 2    C     170      64        True  22.145329

# %% [markdown]
# ### Plot

# %%
df = pd.DataFrame(
    {
        'height': np.random.normal(loc=165, scale=10, size=100).astype(np.int),
        'weight': np.random.normal(loc=60, scale=20, size=100).astype(np.int),
    }
)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   after removing the cwd from sys.path.
#     height  weight
# 0      171      40
# 1      170      73
# 2      162      55
# 3      181      96
# 4      142      84
# ..     ...     ...
# 95     171      29
# 96     162      74
# 97     162      36
# 98     172      48
# 99     174      28
#
# [100 rows x 2 columns]

# %%
df['BMI'] = df['weight'] / ((df['height'] / 100) ** 2)
df
# Out:
#     height  weight        BMI
# 0      171      40  13.679423
# 1      170      73  25.259516
# 2      162      55  20.957171
# 3      181      96  29.303135
# 4      142      84  41.658401
# ..     ...     ...        ...
# 95     171      29   9.917581
# 96     162      74  28.196921
# 97     162      36  13.717421
# 98     172      48  16.224986
# 99     174      28   9.248249
#
# [100 rows x 3 columns]

# %%
plt.plot(df['height'])

# %%
plt.hist(df['height'])
# Out:
# (array([ 1.,  1.,  7., 10., 22., 27., 16., 12.,  2.,  2.]),
#  array([130. , 136.4, 142.8, 149.2, 155.6, 162. , 168.4, 174.8, 181.2,
#         187.6, 194. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['BMI'])
# Out:
# (array([ 3.,  2.,  7., 24., 17., 18.,  8., 12.,  6.,  3.]),
#  array([-1.15736276,  3.12421363,  7.40579002, 11.6873664 , 15.96894279,
#         20.25051918, 24.53209556, 28.81367195, 33.09524834, 37.37682472,
#         41.65840111]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(df['height'], df['weight'])

# %% [markdown]
# ### Save and Read File

# %%
df.to_csv('pandas.csv', index=None)

# %%
df_read = pd.read_csv('pandas.csv')
df_read
# Out:
#     height  weight        BMI
# 0      171      40  13.679423
# 1      170      73  25.259516
# 2      162      55  20.957171
# 3      181      96  29.303135
# 4      142      84  41.658401
# ..     ...     ...        ...
# 95     171      29   9.917581
# 96     162      74  28.196921
# 97     162      36  13.717421
# 98     172      48  16.224986
# 99     174      28   9.248249
#
# [100 rows x 3 columns]

# %%
# CSV, excel
